# %%
import pandas as pd
from pandas_datareader import data as pdr
import numpy as np
import datetime as date
import matplotlib.pyplot as plt

# %%
startdate = date.datetime(2019, 3, 20)
enddate = date.datetime(2020, 3, 20)
tag = 'GFNORTEO.MX'
data = pdr.get_data_yahoo(tag, start = startdate, end = enddate)

# %%
data.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2019-03-20  107.489998  101.209999  102.599998  105.330002  8519758.0
# 2019-03-21  105.690002  103.809998  104.610001  105.459999  5770973.0
# 2019-03-22  105.889999  100.019997  104.709999  101.239998  5821815.0
# 2019-03-25  105.279999  101.800003  101.809998  105.000000  4285801.0
# 2019-03-26  106.139999  104.209999  104.860001  105.180000  6735171.0
#
#              Adj Close
# Date
# 2019-03-20   99.885101
# 2019-03-21  100.008377
# 2019-03-22   96.006523
# 2019-03-25   99.572159
# 2019-03-26   99.742851

# %%
# %matplotlib inline 
fig = plt.figure(figsize = (16,8))
data.Close.plot()
plt.grid()

# %%
def ROC(df, n):
    M = df['Close'].diff(n - 1)
    N = df['Close'].shift(n - 1)
    ROC = pd.Series(M/N, name = 'ROC_' + str(n))
    df = df.join(ROC)
    Cr = pd.Series(df['Close'].shift(1), name = 'Cr')
    df = df.join(Cr)
    ROCr = pd.Series(ROC.shift(1), name = 'ROC_' + str(n) + '_r')
    df = df.join(ROCr)
    df['Recomendación'] = '-'
    
    df.loc[((ROC > 0) & (ROCr < 0)), 'Recomendación'] = 'Se recomienda COMPRAR la acción.'
    df.loc[((ROC < 0) & (ROCr > 0)), 'Recomendación'] = 'Se recomienda VENDER la acción.'
    df.loc[((df['Close'] < Cr) & ((ROC > 0) & (ROCr < 0) & (ROC > ROCr))), 'Recomendación'] = 'Se recomienda COMPRAR la acción. (DIV)'
    df.loc[((df['Close'] > Cr) & ((ROC < 0) & (ROCr > 0) & (ROC < ROCr))), 'Recomendación'] = 'Se recomienda VENDER la acción. (DIV)'    
    
    return df

# %%
df2 = ROC(data, 10)

# %%
fig = plt.figure(figsize = (16,8))
plt.subplot(2, 1, 1)
plt.plot(df2.Close)
plt.title('Precio del Indice')
plt.grid()
plt.subplot(2, 1, 2)
plt.plot(df2.ROC_10)
plt.axhline(y=0, color= 'r')
plt.grid()
plt.show()
df2.loc[df2['Recomendación'] != '-',['Close', 'ROC_10', 'Recomendación']]
#df2[['Close', 'ROC_10', 'Recomendación']]
# Out:
#                  Close    ROC_10                           Recomendación
# Date
# 2019-05-02  114.220001 -0.028989         Se recomienda VENDER la acción.
# 2019-05-30  113.430000  0.014852        Se recomienda COMPRAR la acción.
# 2019-05-31  106.589996 -0.038864         Se recomienda VENDER la acción.
# 2019-06-10  107.239998  0.000187        Se recomienda COMPRAR la acción.
# 2019-06-11  106.860001 -0.035734         Se recomienda VENDER la acción.
# 2019-06-17  107.650002  0.004198        Se recomienda COMPRAR la acción.
# 2019-07-09  108.230003 -0.034350         Se recomienda VENDER la acción.
# 2019-08-08   96.120003  0.011151        Se recomienda COMPRAR la acción.
# 2019-08-12   97.349998 -0.004601         Se recomienda VENDER la acción.
# 2019-08-14   94.370003  0.019445  Se recomienda COMPRAR la acción. (DIV)
# 2019-09-24  106.419998 -0.026973         Se recomienda VENDER la acción.
# 2019-10-04  110.419998  0.010709        Se recomienda COMPRAR la acción.
# 2019-10-09  105.989998 -0.007584   Se recomienda VENDER la acción. (DIV)
# 2019-10-10  107.930000  0.009824        Se recomienda COMPRAR la acción.
# 2019-10-17  108.400002 -0.018294         Se recomienda VENDER la acción.
# 2019-10-21  106.989998  0.011152  Se recomienda COMPRAR la acción. (DIV)
# 2019-10-25  101.680000 -0.081066         Se recomienda VENDER la acción.
# 2019-11-07  105.440002  0.036979        Se recomienda COMPRAR la acción.
# 2019-11-08  102.949997 -0.001358         Se recomienda VENDER la acción.
# 2019-11-11  102.620003  0.011533  Se recomienda COMPRAR la acción. (DIV)
# 2019-11-12   99.769997 -0.031547         Se recomienda VENDER la acción.
# 2019-11-19  105.849998  0.019259        Se recomienda COMPRAR la acción.
# 2019-11-29  102.940002 -0.001455         Se recomienda VENDER la acción.
# 2019-12-11  106.260002  0.024390        Se recomienda COMPRAR la acción.
# 2019-12-27  108.919998 -0.011705         Se recomienda VENDER la acción.
# 2020-01-06  110.080002  0.012416        Se recomienda COMPRAR la acción.
# 2020-01-07  106.879997 -0.031533         Se recomienda VENDER la acción.
# 2020-01-09  112.870003  0.029554        Se recomienda COMPRAR la acción.
# 2020-01-15  107.870003 -0.016323         Se recomienda VENDER la acción.
# 2020-01-16  111.040001  0.009822        Se recomienda COMPRAR la acción.
# 2020-02-07  113.989998 -0.001402         Se recomienda VENDER la acción.
# 2020-02-10  114.129997  0.006393        Se recomienda COMPRAR la acción.
# 2020-02-14  114.959999 -0.010075         Se recomienda VENDER la acción.
# 2020-02-17  116.889999  0.004598        Se recomienda COMPRAR la acción.
# 2020-02-18  115.959999 -0.000948         Se recomienda VENDER la acción.
# 2020-02-19  116.540001  0.003271        Se recomienda COMPRAR la acción.
# 2020-02-24  112.910004 -0.020983         Se recomienda VENDER la acción.
