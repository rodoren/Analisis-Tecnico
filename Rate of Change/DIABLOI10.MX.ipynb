# %%
import pandas as pd
from pandas_datareader import data as pdr
import numpy as np
import datetime as date
import matplotlib.pyplot as plt

# %%
startdate = date.datetime(2019, 3, 20)
enddate = date.datetime(2020, 3, 20)
tag = 'DIABLOI10.MX'
data = pdr.get_data_yahoo(tag, start = startdate, end = enddate)

# %%
data.head()
# Out:
#              High    Low   Open  Close  Volume  Adj Close
# Date
# 2019-03-20  12.50  12.38  12.50  12.41    5642      12.41
# 2019-03-21  12.43  12.30  12.41  12.43   24787      12.43
# 2019-03-22  12.75  12.50  12.63  12.75    5477      12.75
# 2019-03-25  12.75  12.38  12.75  12.64    2565      12.64
# 2019-03-26  12.64  12.60  12.60  12.61    2390      12.61

# %%
# %matplotlib inline 
fig = plt.figure(figsize = (16,8))
data.Close.plot()
plt.grid()

# %%
def ROC(df, n):
    M = df['Close'].diff(n - 1)
    N = df['Close'].shift(n - 1)
    ROC = pd.Series(M/N, name = 'ROC_' + str(n))
    df = df.join(ROC)
    Cr = pd.Series(df['Close'].shift(1), name = 'Cr')
    df = df.join(Cr)
    ROCr = pd.Series(ROC.shift(1), name = 'ROC_' + str(n) + '_r')
    df = df.join(ROCr)
    df['Recomendación'] = '-'
    
    df.loc[((ROC > 0) & (ROCr < 0)), 'Recomendación'] = 'Se recomienda COMPRAR la acción.'
    df.loc[((ROC < 0) & (ROCr > 0)), 'Recomendación'] = 'Se recomienda VENDER la acción.'
    df.loc[((df['Close'] < Cr) & ((ROC > 0) & (ROCr < 0) & (ROC > ROCr))), 'Recomendación'] = 'Se recomienda COMPRAR la acción. (DIV)'
    df.loc[((df['Close'] > Cr) & ((ROC < 0) & (ROCr > 0) & (ROC < ROCr))), 'Recomendación'] = 'Se recomienda VENDER la acción. (DIV)'    
    
    return df

# %%
df2 = ROC(data, 10)

# %%
fig = plt.figure(figsize = (16,8))
plt.subplot(2, 1, 1)
plt.plot(df2.Close)
plt.title('Precio del Indice')
plt.grid()
plt.subplot(2, 1, 2)
plt.plot(df2.ROC_10)
plt.axhline(y=0, color= 'r')
plt.grid()
plt.show()
df2.loc[df2['Recomendación'] != '-',['Close', 'ROC_10', 'Recomendación']]
#df2[['Close', 'ROC_10', 'Recomendación']]
# Out:
#              Close    ROC_10                           Recomendación
# Date
# 2019-04-04  12.310 -0.034510         Se recomienda VENDER la acción.
# 2019-04-23  12.030  0.008382        Se recomienda COMPRAR la acción.
# 2019-04-25  12.080 -0.009024         Se recomienda VENDER la acción.
# 2019-05-02  12.190  0.012458        Se recomienda COMPRAR la acción.
# 2019-06-03  12.590 -0.002377         Se recomienda VENDER la acción.
# 2019-06-20  12.490 -0.000800         Se recomienda VENDER la acción.
# 2019-06-21  12.520  0.008052        Se recomienda COMPRAR la acción.
# 2019-06-25  12.380 -0.001613         Se recomienda VENDER la acción.
# 2019-07-02  12.600  0.001590        Se recomienda COMPRAR la acción.
# 2019-08-26  13.740 -0.013640         Se recomienda VENDER la acción.
# 2019-09-19  12.930  0.003882        Se recomienda COMPRAR la acción.
# 2019-09-20  12.780 -0.006221         Se recomienda VENDER la acción.
# 2019-09-25  12.960  0.004651        Se recomienda COMPRAR la acción.
# 2019-10-01  12.900 -0.000775   Se recomienda VENDER la acción. (DIV)
# 2019-10-02  13.130  0.015468        Se recomienda COMPRAR la acción.
# 2019-10-15  12.980 -0.011424   Se recomienda VENDER la acción. (DIV)
# 2019-10-18  13.050  0.003075        Se recomienda COMPRAR la acción.
# 2019-10-21  12.980 -0.009160         Se recomienda VENDER la acción.
# 2019-10-31  13.100  0.003831        Se recomienda COMPRAR la acción.
# 2019-11-01  12.970 -0.000770         Se recomienda VENDER la acción.
# 2019-11-06  12.860  0.006260  Se recomienda COMPRAR la acción. (DIV)
# 2019-11-07  12.740 -0.012403         Se recomienda VENDER la acción.
# 2019-11-08  12.830  0.001561        Se recomienda COMPRAR la acción.
# 2019-11-11  12.870 -0.007710   Se recomienda VENDER la acción. (DIV)
# 2019-11-12  12.990  0.000770        Se recomienda COMPRAR la acción.
# 2019-11-13  12.990 -0.008397         Se recomienda VENDER la acción.
# 2019-11-14  13.000  0.002313        Se recomienda COMPRAR la acción.
# 2019-11-19  12.860 -0.004644         Se recomienda VENDER la acción.
# 2019-11-20  12.880  0.001555        Se recomienda COMPRAR la acción.
# 2019-12-11  12.990 -0.003834         Se recomienda VENDER la acción.
# 2019-12-27  12.750  0.006314        Se recomienda COMPRAR la acción.
# 2020-01-08  12.690 -0.003142         Se recomienda VENDER la acción.
# 2020-01-10  12.780  0.002353        Se recomienda COMPRAR la acción.
# 2020-01-13  12.600 -0.023256         Se recomienda VENDER la acción.
# 2020-01-27  12.695  0.005943        Se recomienda COMPRAR la acción.
# 2020-01-28  12.550 -0.011032         Se recomienda VENDER la acción.
# 2020-01-29  12.430  0.012215  Se recomienda COMPRAR la acción. (DIV)
# 2020-02-10  12.660 -0.002757         Se recomienda VENDER la acción.
# 2020-02-12  12.450  0.001609  Se recomienda COMPRAR la acción. (DIV)
# 2020-02-13  12.550 -0.000796   Se recomienda VENDER la acción. (DIV)
# 2020-02-20  12.890  0.012569        Se recomienda COMPRAR la acción.
